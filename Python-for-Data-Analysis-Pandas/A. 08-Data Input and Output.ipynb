# %%
import numpy as np
import pandas as pd

# %%
pwd
# Out:
# 'C:\\Users\\KIIT\\Desktop\\Udemy Courses\\Data Science and Machine Learning\\My Learning\\03-Python-for-Data-Analysis-Pandas'

# %%
pd.read_csv('example')
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df=pd.read_csv('example')

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df.to_csv('My_output',index=False)

# %%
pd.read_csv('My_output')
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
pd.read_excel('Excel_Sample.xlsx',sheet_name='Sheet1')
# Out:
#    Unnamed: 0   a   b   c   d
# 0           0   0   1   2   3
# 1           1   4   5   6   7
# 2           2   8   9  10  11
# 3           3  12  13  14  15

# %%
df.to_excel('Excel_Sample2.xlsx',sheet_name='NewSheet')

# %%
data = pd.read_html('https://in.godaddy.com/pro/hosting/web-hosting')

# %%
data[0]
# Out:
#                                            Unnamed: 0  \
# 0                                            Websites
# 1                                          Disk space
# 2                                  Monthly bandwidth﻿
# 3                                                CPUs
# 4                                              Memory
# 5                                  Input/output (I/O)
# 6                                     Number of files
# 7                                Free SSL Certificate
# 8                             Free Domain - 1st year﻿
# 9                                     Site management
# 10                                   Operating System
# 11                                      Control Panel
# 12                                          FTP users
# 13                                    MySQL databases
# 14                            Database backup/restore
# 15                             Direct database access
# 16                                     DNS management
# 17                                   External domains
# 18                                         Subdomains
# 19                                      Alias domains
# 20                                          WordPress
# 21                          1-click WordPress install
# 22                Streamlined WordPress website setup
# 23  Prototype sites in minutes with our highly-rat...
# 24                         Royalty-free image library
# 25                                        Programming
# 26                        PHP 7.3, 7.2, 7.1, 7.0, 5.6
# 27                                             Python
# 28                                               Perl
# 29                                            Node.js
# 30                                    cPanel features
# 31                      Installatron (125+ free apps)
# 32                                         phpMyAdmin
# 33                     Password protected directories
# 34                          SSH access (secure shell)
# 35                                FTP over SSL (FTPS)
# 36                                    Raw access logs
# 37                                    Site statistics
# 38                                          Cron jobs
# 39                                       File manager
# 40                                        ImageMagick
# 41                                     Custom PHP.ini
# 42                                           Web mail
# 43                                           Exchange
# 44                                     Auto-responder
# 45                     Fraud, virus & spam protection
# 46  Email privacy & protection with 256-bit encryp...
# 47                                              Other
# 48                       1-click GoDaddy domain setup
# 49             1-click resources upgrade (CPU/RAM/IO)
# 50                            99.9% uptime guarantee^
# 51                       30-day money-back guarantee﻿
#
#    Starter  As low as ₹ 99.00/mo  Add to Cart  \
# 0                                           1
# 1                                       30 GB
# 2                                   Unmetered
# 3                                           1
# 4                                       256MB
# 5                                         512
# 6                              Up to 2,50,000
# 7                                           —
# 8                                           —
# 9                                         NaN
# 10                                      Linux
# 11                                     cPanel
# 12                                         50
# 13                                   1 x 1 GB
# 14                                        NaN
# 15                                        NaN
# 16                                        NaN
# 17                                  Unlimited
# 18                                         25
# 19                                  Unlimited
# 20                                        NaN
# 21                                        NaN
# 22                                        NaN
# 23                                        NaN
# 24                                        NaN
# 25                                        NaN
# 26                                        NaN
# 27                                        NaN
# 28                                        NaN
# 29                                        NaN
# 30                                    86.0.25
# 31                                        NaN
# 32                                        NaN
# 33                                        NaN
# 34                                        NaN
# 35                                        NaN
# 36                                        NaN
# 37                                        NaN
# 38                                        NaN
# 39                                        NaN
# 40                                        NaN
# 41                                        NaN
# 42                                        NaN
# 43                                        NaN
# 44                                        NaN
# 45                                        NaN
# 46                                        NaN
# 47                                        NaN
# 48                                        NaN
# 49                                        NaN
# 50                                        NaN
# 51                                        NaN
#
#    Economy  As low as ₹ 199.00/mo  Add to Cart  \
# 0                                            1
# 1                                       100 GB
# 2                                    Unmetered
# 3                                            1
# 4                                        512MB
# 5                                         1024
# 6                               Up to 2,50,000
# 7                                            —
# 8                                          NaN
# 9                                          NaN
# 10                                       Linux
# 11                                      cPanel
# 12                                          50
# 13                                   10 x 1 GB
# 14                                         NaN
# 15                                         NaN
# 16                                         NaN
# 17                                   Unlimited
# 18                                          25
# 19                                   Unlimited
# 20                                         NaN
# 21                                         NaN
# 22                                         NaN
# 23                                         NaN
# 24                                         NaN
# 25                                         NaN
# 26                                         NaN
# 27                                         NaN
# 28                                         NaN
# 29                                         NaN
# 30                                     86.0.25
# 31                                         NaN
# 32                                         NaN
# 33                                         NaN
# 34                                         NaN
# 35                                         NaN
# 36                                         NaN
# 37                                         NaN
# 38                                         NaN
# 39                                         NaN
# 40                                         NaN
# 41                                         NaN
# 42                                         NaN
# 43                                         NaN
# 44                                         NaN
# 45                                         NaN
# 46                                         NaN
# 47                                         NaN
# 48                                         NaN
# 49                                         NaN
# 50                                         NaN
# 51                                         NaN
#
#    Deluxe  As low as ₹ 299.00/mo  Add to Cart  \
# 0                                   Unlimited
# 1                                   Unlimited
# 2                                   Unmetered
# 3                                           1
# 4                                       512MB
# 5                                        1024
# 6                              Up to 2,50,000
# 7                                           —
# 8                                         NaN
# 9                                         NaN
# 10                                      Linux
# 11                                     cPanel
# 12                                         50
# 13                                  25 x 1 GB
# 14                                        NaN
# 15                                        NaN
# 16                                        NaN
# 17                                  Unlimited
# 18                                  Unlimited
# 19                                  Unlimited
# 20                                        NaN
# 21                                        NaN
# 22                                        NaN
# 23                                        NaN
# 24                                        NaN
# 25                                        NaN
# 26                                        NaN
# 27                                        NaN
# 28                                        NaN
# 29                                        NaN
# 30                                    86.0.25
# 31                                        NaN
# 32                                        NaN
# 33                                        NaN
# 34                                        NaN
# 35                                        NaN
# 36                                        NaN
# 37                                        NaN
# 38                                        NaN
# 39                                        NaN
# 40                                        NaN
# 41                                        NaN
# 42                                        NaN
# 43                                        NaN
# 44                                        NaN
# 45                                        NaN
# 46                                        NaN
# 47                                        NaN
# 48                                        NaN
# 49                                        NaN
# 50                                        NaN
# 51                                        NaN
#
#    Ultimate  As low as ₹ 449.00/mo  Add to Cart
# 0                                     Unlimited
# 1                                     Unlimited
# 2                                     Unmetered
# 3                                             2
# 4                                           1GB
# 5                                          1024
# 6                                Up to 2,50,000
# 7                     1 SSL, free for 1st year﻿
# 8                                           NaN
# 9                                           NaN
# 10                                        Linux
# 11                                       cPanel
# 12                                    Unlimited
# 13                             Unlimited x 1 GB
# 14                                          NaN
# 15                                          NaN
# 16                                  Premium DNS
# 17                                    Unlimited
# 18                                    Unlimited
# 19                                    Unlimited
# 20                                          NaN
# 21                                          NaN
# 22                                          NaN
# 23                                          NaN
# 24                                          NaN
# 25                                          NaN
# 26                                          NaN
# 27                                          NaN
# 28                                          NaN
# 29                                          NaN
# 30                                      86.0.25
# 31                                          NaN
# 32                                          NaN
# 33                                          NaN
# 34                                          NaN
# 35                                          NaN
# 36                                          NaN
# 37                                          NaN
# 38                                          NaN
# 39                                          NaN
# 40                                          NaN
# 41                                          NaN
# 42                                          NaN
# 43                                          NaN
# 44                                          NaN
# 45                                          NaN
# 46                                          NaN
# 47                                          NaN
# 48                                          NaN
# 49                                          NaN
# 50                                          NaN
# 51                                          NaN

# %%
data[0].head()
# Out:
#            Unnamed: 0 Starter  As low as ₹ 99.00/mo  Add to Cart  \
# 0            Websites                                          1
# 1          Disk space                                      30 GB
# 2  Monthly bandwidth﻿                                  Unmetered
# 3                CPUs                                          1
# 4              Memory                                      256MB
#
#   Economy  As low as ₹ 199.00/mo  Add to Cart  \
# 0                                           1
# 1                                      100 GB
# 2                                   Unmetered
# 3                                           1
# 4                                       512MB
#
#   Deluxe  As low as ₹ 299.00/mo  Add to Cart  \
# 0                                  Unlimited
# 1                                  Unlimited
# 2                                  Unmetered
# 3                                          1
# 4                                      512MB
#
#   Ultimate  As low as ₹ 449.00/mo  Add to Cart
# 0                                    Unlimited
# 1                                    Unlimited
# 2                                    Unmetered
# 3                                            2
# 4                                          1GB

# %%
from sqlalchemy import create_engine

# %%
engine= create_engine('sqlite:///:memory:')

# %%
df
# Out:
#     a   b   c   d
# 0   0   1   2   3
# 1   4   5   6   7
# 2   8   9  10  11
# 3  12  13  14  15

# %%
df.to_sql('data', engine)

# %%
sql_df = pd.read_sql('data',con=engine)

# %%
sql_df
# Out:
#    index   a   b   c   d
# 0      0   0   1   2   3
# 1      1   4   5   6   7
# 2      2   8   9  10  11
# 3      3  12  13  14  15
